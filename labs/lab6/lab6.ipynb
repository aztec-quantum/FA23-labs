# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, Aer
from qiskit.visualization import plot_histogram

# %% [markdown]
# ## Lab 6 - Circuit from Truth Table
# ---
# This labs objective is to push your problem solving and debugging skills in the quantum domain. We have discussed how truth tables can be used to represent logical operations. The real challenge is taking a complex logical operation such as the adder's we have seen and creating it from a truth table. This problem is equally complex, yet very similiar to the examples we have seen so far. In order to solve this problem you will need three different gates, XGate, CXGate, CCXGate.
#
# #### Decrementor Circuit
# - Use the truth table below to implement a decrementor circuit. Given a qubit string of size 2 -> q1q0, return q1q0 - 1. Use a similiar technique to the incrementor circuit we saw in the lecture slides. The truth table below will show you the expected output for the given inputs. Make sure you pay attention to the order of the qubits, as it is reversed compared to the incrementor circuit.
#
# Hint: Use XGate to change your inputs and validate that your circuit is working properly, make sure to verify the edge cases!!
#
#
#
# | q0 | q1 | Output
# |----|----|-----|
# | 0 | 0 | 11 |
# | 0 | 1 | 00 |
# | 1 | 0 | 01 |
# | 1 | 1 | 10 |

# %%
qreg_q = QuantumRegister(6, 'q')
creg_c = ClassicalRegister(2, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)
# YOUR CODE STARTS HERE



# YOUR CODE ENDS HERE
circuit.barrier()
circuit.measure(qreg_q[3], creg_c[0])
circuit.measure(qreg_q[4], creg_c[1])

job = execute(circuit, backend = Aer.get_backend('qasm_simulator'), shots = 1000)
plot_histogram(job.result().get_counts(circuit))

# %%
circuit.draw(output='mpl')
